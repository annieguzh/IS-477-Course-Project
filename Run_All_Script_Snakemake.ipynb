# %%
! snakemake --cores 1 --delete-all-output
# Out:
# Building DAG of jobs...
# Deleting results/data_storage_summary.txt
# Deleting data/raw/food_inspections.csv
# Deleting data/raw/food_inspections.sha256
# Deleting data/raw/zhvi.csv
# Deleting data/raw/zhvi.sha256
# Deleting data/processed/integrated_food_housing.csv
# Deleting data/processed/integrated_food_housing.sha256
# Deleting results/integrated_data_summary.txt
# Deleting data/processed/food_inspections_cleaned.csv
# Deleting data/processed/food_inspections_cleaned.sha256
# Deleting data/processed/zhvi_cleaned.csv
# Deleting data/processed/zhvi_cleaned.sha256
# Deleting results/zip_level_summary.csv
# Deleting results/correlation_heatmap.png
# Deleting results/risk_correlations.txt
# Deleting results/high_risk_vs_zhvi_scatter.png
# Deleting results/low_risk_vs_zhvi_scatter.png
# Deleting results/housing_by_high_risk_tertiles.png
# Deleting results/housing_by_low_risk_tertiles.png
# Deleting results/risk_by_price_quartiles.csv

# %%
! snakemake --cores 1
# Out:
# Assuming unrestricted shared filesystem usage.
# host: wirelessprv-10-192-198-155.near.illinois.edu
# Building DAG of jobs...
# Using shell: /bin/bash
# Provided cores: 1 (use --cores to define parallelism)
# Rules claiming more threads will be scaled down.
# Job stats:
# job                  count
# -----------------  -------
# analyze_visualize        1
# clean_food               1
# clean_zhvi               1
# data_acquisition         1
# data_storage             1
# integrate_data           1
# run_all                  1
# total                    7
#
# Select jobs to execute...
# Execute 1 jobs...
#
# [Sun Dec  7 17:38:08 2025]
# localrule data_acquisition:
#     output: data/raw/food_inspections.csv, data/raw/food_inspections.sha256, data/raw/zhvi.csv, data/raw/zhvi.sha256
#     jobid: 2
#     reason: Missing output files: data/raw/zhvi.csv, data/raw/food_inspections.csv
#     resources: tmpdir=/var/folders/sh/z8h893ps7k92l_crm8fmjw800000gn/T
# Fetching records 0 to 50000...
# ...
